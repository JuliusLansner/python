# %% [markdown]
# # House data

# %% [markdown]
# ## Environment

# %%
# import pandas for structuring the data
import pandas as pd
# import numpy for numerical analysis
import numpy as np

# %% [markdown]
# ## Data Input

# %%
df = pd.read_csv('C:\\Users\\Oscar\\Documents\\BI\\house-data.csv', index_col=None, na_values=['NA'])

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
# After data input, we have to check for missing values in the data. 
# If this process is'nt done it can lead to error/break in program
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# As seen above the data don't has any mising felts of data.

# %%
df['date'] = pd.to_datetime(df['date']) # Change date format to something more readable

# %%
df['bathrooms'] = df['bathrooms'].astype(int)
df['floors'] = df['floors'].astype(int)

# %%
df.drop(['id', 'waterfront', 'view', 'yr_renovated', 'sqft_basement'], axis=1)
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3          1         1180      5650
# 1     2014-12-09  538000.0         3          2         2570      7242
# 2     2015-02-25  180000.0         2          1          770     10000
# 3     2014-12-09  604000.0         4          3         1960      5000
# 4     2015-02-18  510000.0         3          2         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21608 2014-05-21  360000.0         3          2         1530      1131
# 21609 2015-02-23  400000.0         4          2         2310      5813
# 21610 2014-06-23  402101.0         2          0         1020      1350
# 21611 2015-01-16  400000.0         3          2         1600      2388
# 21612 2014-10-15  325000.0         2          0         1020      1076
#
#        floors  condition  grade  sqft_above  yr_built  zipcode      lat  \
# ...

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %% [markdown]
# ## Analise the cleaning operations you have experienced there, in terms of:
#
# ### a. What type of error have been checked for?:
# 1. Missing values in different columns. These where identitfyed by:
# ```python
# df.isnull().sum()
# ```
# 2. These columns with high number of missing data (only has static valus, but no vailded impact on data set ) in ('id', 'waterfront', 'view', 'yr_renovated', 'sqft_basement') where drop do to being less informativ.
#
# ### b. Has this type of error been found?
# 1. No missing values where, it had static values like 0 and os no.
# 2. High missing values there were founded: 'id', 'waterfront', 'view', 'yr_renovated', 'sqft_basement'.
#
# ### c. If it has been found, how it has been recovered?
# 1. Change date format to something more readable.
# 2. High number of missing values ('id', 'waterfront', 'view', 'yr_renovated', 'sqft_basement') were dropped.
# 3. Bathrooms and floors cahnge data type from float to int.
